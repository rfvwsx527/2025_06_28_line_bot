# %%
from google import genai

client = genai.Client()
response = client.models.generate_content_stream(
    model="gemini-2.5-flash",
    contents=["AI是如何工作的(請使用繁體中文回答)?"],
)
for chunk in response:
    print(chunk.text)
# Out:
# AI（人工智慧，Artificial Intelligence）的核心工作原理，可以概括為「**從數據中學習模式，然後利用這些模式來做出預測、判斷或決策**」。
#
# 以下將其分解為幾個關鍵
# 步驟和概念：
#
# ### AI 的核心工作原理
#
# 1.  **數據（Data）：AI 的燃料**
#     *   **收集與準備：** AI 學習的基礎是大量的數據。這些數據可以是文字、圖片、
# 聲音、數字、行為記錄等。例如，如果要讓 AI 識別貓，就需要給它看成千上萬張貓的圖片（以及非貓的圖片）。
#     *   **特徵工程：** 數據會
# 被轉換成 AI 模型能夠理解的「特徵」（Features），即數據中具有區分性或描述性的屬性。例如，一張貓的圖片，其特徵可能是毛色、眼睛形狀、耳朵尖度
# 等。
#
# 2.  **模型與演算法（Model & Algorithm）：AI 的大腦與學習規則**
#     *   **演算法：** 這些是指導 AI 如何從數據中學習的數學規則和步驟
# 。例如，機器學習中有很多種演算法，如決策樹、支持向量機、神經網路等。
#     *   **模型：** 演算法經過數據訓練後形成的結果，它包含了從數據中學習
# 到的模式、規則和內部參數。這個「模型」就是 AI 真正的「大腦」，能夠執行特定任務。
#
# 3.  **訓練過程（Training Process）：AI 的學習階段**
#     *   **輸入數據與
# 標籤：** 在訓練階段，AI 模型會被「餵食」大量的數據。對於監督式學習（最常見的學習方式），這些數據通常帶有「標籤」（Label），即正確答案。例如，給
# 模型一張貓的圖片，同時告訴它「這是貓」。
#     *   **模式識別與參數調整：** 模型會嘗試在數據中找出規律和模式，並不斷調整其內部的「參數」（Parameters），
# 以使預測結果與正確答案之間的誤差最小化。這個過程就像一個學生在做練習題，做錯了就訂正，直到對大部分題目都能給出正確答案。
#     *   **損失函數與
# 優化器：** 在這個過程中，會有一個「損失函數」（Loss Function）來衡量模型的預測與真實結果之間的差距（誤差），然後「優化器」（Optimizer）會根據這個誤差來調整模型的參數，試圖
# 讓損失最小。
#
# 4.  **預測與應用（Prediction & Application）：AI 的實踐階段**
#     *   **新數據輸入：** 當模型訓練完成後，就可以將其部署到實際應用中。這
# 時，當有新的、模型從未見過的數據輸入時（例如，一張新的圖片），模型會利用它在訓練階段學到的模式和規則來進行分析。
#     *   **輸出結果：** 模型會根據其內部
# 邏輯，對新數據做出預測、分類、判斷或生成內容。例如，識別這張新圖片是否為貓，或根據輸入的文字生成新的語句。
#
# 5.  **持續優化（Continuous
#  Optimization）：AI 的進化**
#     *   AI 模型並非一勞永逸。在實際應用中，它可能會遇到新的、不同類型的數據，或者其性能可能隨時間下降。
#     *   因此，AI
# 系統通常會透過收集新的數據、接收用戶回饋，或在新的任務上進行再訓練，來不斷地改進和優化其模型，使其表現更準確、更智能。
#
# ### 簡單的比喻
#
#
# 想像你正在教一個孩子（AI）如何辨認蘋果。
#
# 1.  **數據：** 你給孩子看成千上萬個蘋果的圖片和實物，以及梨子、香蕉等其他水果的圖片。每次
# 你都會告訴他：「這個是蘋果」、「這個不是蘋果」。
# 2.  **模型與演算法：** 孩子的大腦（模型）開始學習什麼是蘋果的共同特徵（圓形、紅色/綠色、
# 有蒂、甜味等），並建立一套判斷規則（演算法）。
# 3.  **訓練過程：** 孩子會不斷地觀察、學習、記憶，並嘗試區分。當他把蘋果錯認為
# 梨子時，你會糾正他，他就會調整自己的判斷規則。
# 4.  **預測與應用：** 當孩子學會後，你給他一個從沒見過的新水果，他就能根據之前
# 學到的經驗判斷：「這是蘋果！」
# 5.  **持續優化：** 如果孩子偶爾會把紅色的燈籠椒誤認為蘋果，你就會再次糾正他，他會進一步完善對蘋果的定義
# 。
#
# ### 總結
#
# AI 的工作原理就是透過**大量數據**的餵養，利用**演算法**訓練出一個能夠識別、學習和模仿人類智能的**模型**，然後這個模型就能夠在新的
# 情境下**做出預測或決策**，並且這個過程可以透過**持續優化**不斷提升其效能。

# %%
import PIL.Image
from google import genai
from IPython.display import display, Markdown

client = genai.Client()
image = PIL.Image.open('bear.jpg')
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[image, "請告訴我這是什麼動物,還有關於它的一些資訊"]
)

display(Markdown(response.text))
# Out:
# 這是一隻**棕熊** (Brown Bear)。
#
# 棕熊是熊科動物中分佈最廣的物種之一，在北美洲，牠們常被稱為**灰熊** (Grizzly Bear) 或 **科迪亞克熊** (Kodiak Bear，特指阿拉斯加的巨型棕熊)。
#
# 以下是關於棕熊的一些資訊：
#
# 1.  **外觀特徵：**
#     *   **體型碩大：** 是陸地上體型最大的食肉動物之一（儘管牠們是雜食性動物）。成年雄性體重可達數百公斤，甚至超過600公斤。
#     *   **毛髮：** 毛色多變，從淺棕色到深棕色，甚至接近黑色，取決於地理分佈和個體差異。背部通常有較長的毛髮，看起來有些蓬鬆。
#     *   **肩部隆起：** 許多棕熊（尤其是灰熊）在肩部有明顯的肌肉隆起，這是牠們強大前肢力量的來源。
#     *   **爪子：** 擁有長而彎曲的非伸縮性爪子，非常適合挖土、撕裂和捕食，但不像貓科動物那樣善於爬樹。
#     *   **頭部：** 頭部較大，眼睛相對較小，耳朵圓而短。
#
# 2.  **棲息地與分佈：**
#     *   棕熊廣泛分佈於北美洲、歐洲和亞洲的許多地區，是現存熊類中分佈最廣的。
#     *   牠們的棲息地多樣，包括森林、山區、草原、苔原和沿海地區。通常喜歡有茂密植被和水源的區域。
#
# 3.  **食性：**
#     *   棕熊是**雜食性動物**，食譜非常廣泛，會根據季節和食物供應變化。
#     *   牠們的食物包括漿果、堅果、植物根莖、蘑菇、昆蟲、魚類（尤其是鮭魚）、小型哺乳動物、鳥蛋，甚至腐肉。
#     *   在某些地區，牠們也會捕食大型有蹄類動物的幼崽。
#
# 4.  **行為特點：**
#     *   **獨居：** 大多數棕熊是獨居動物，除了繁殖期和母熊撫養幼崽期間。
#     *   **冬眠：** 在寒冷地區，棕熊會進入冬眠狀態，利用體內儲存的脂肪度過食物稀缺的冬季。
#     *   **嗅覺靈敏：** 牠們的嗅覺極其靈敏，遠超牠們的視力或聽力，可以嗅探到數公里外的食物。
#     *   **智商：** 棕熊非常聰明，有很強的學習能力和記憶力。
#     *   **攻擊性：** 雖然通常會避開人類，但若受到威脅（尤其是有幼崽的母熊）、被食物吸引或感到受侵犯時，棕熊會變得極具攻擊性。
#
# 5.  **保育狀況：**
#     *   全球範圍內，棕熊的整體保育狀況被列為「無危」(Least Concern)。
#     *   但在某些地區，由於棲息地喪失、人類活動干擾和非法狩獵，牠們的數量仍在下降，面臨威脅。
#
# 棕熊在生態系統中扮演著重要的角色，作為頂級掠食者，牠們有助於維持生態平衡。
